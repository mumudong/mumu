# %%
import pickle
class Fish:
    def __init__(self):
        self.name='小鱼'
f = Fish()
print(f.name)
fish = pickle.dumps(f)
print(fish)
f = pickle.loads(fish)
f.name
# Out:
# 小鱼
# b'\x80\x03c__main__\nFish\nq\x00)\x81q\x01}q\x02X\x04\x00\x00\x00nameq\x03X\x06\x00\x00\x00\xe5\xb0\x8f\xe9\xb1\xbcq\x04sb.'
# '小鱼'

# %%
import numpy as np
import cv2
import pickle
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../opencv/a.JPG')
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
bt = pickle.dumps(img)
result = pickle.loads(bt)
plt.imshow(cv2.cvtColor(result,cv2.COLOR_BGR2RGB))
plt.show()

# %%
import base64
bs64 = base64.b64encode(bt)
tt = base64.b64decode(bs64) 
img = pickle.loads(tt)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
with open("../opencv/a.JPG","rb") as f:  
    # b64encode是编码，b64decode是解码  
#     base64_data = base64.b64encode(f.read())  
    # base64.b64decode(base64data)  
#     print(base64_data)
#     result2 = base64.b64decode(base64_data)
#     print(type(result2))
    nparr = np.fromstring(f.read(), np.uint8)
    img_np = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    # print(img_np.shape)
    cv2.imshow("test",img_np)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
import os
for root, dirs, files in os.walk(".", topdown=True):
    for name in files:
#         print('name---->',name)
        print(os.path.join(root, name))
    for name in dirs:
        print('dir---->',name)
        print(os.path.join(root, name))
# Out:
# .\dict.ipynb
# .\ioutil.ipynb
# .\Logic.ipynb
# .\namedtuple.ipynb
# .\pandas.ipynb
# .\sklearn.ipynb
# .\sql.ipynb
# .\tensorflow.ipynb
# dir----> .ipynb_checkpoints
# .\.ipynb_checkpoints
# dir----> pil
# .\pil
# .\.ipynb_checkpoints\dict-checkpoint.ipynb
# .\.ipynb_checkpoints\ioutil-checkpoint.ipynb
# .\.ipynb_checkpoints\Logic-checkpoint.ipynb
# .\.ipynb_checkpoints\namedtuple-checkpoint.ipynb
# .\.ipynb_checkpoints\pandas-checkpoint.ipynb
# .\.ipynb_checkpoints\sklearn-checkpoint.ipynb
# .\.ipynb_checkpoints\sql-checkpoint.ipynb
# .\.ipynb_checkpoints\tensorflow-checkpoint.ipynb
# .\pil\b.gif
# .\pil\gif.txt
# .\pil\test.jpg
