# %%
import matplotlib.pyplot as plt
import cv2 
import numpy as np

# %%
img = cv2.imread('C:\\Users\\Administrator\\Desktop\\img.png',1)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 

img1 = cv2.imread('C:\\Users\\Administrator\\Desktop\\a.png',1)
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img1 = cv2.resize(img1,(100, 86))

img2 = cv2.imread('C:\\Users\\Administrator\\Desktop\\b.png',1)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2,(100, 86))

img[61:147,106:206] = img1
plt.figure(figsize=(15,12))

img[61:147,334:434] = img2 

print(img.shape)
plt.imshow(img)
plt.show()
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
cv2.imwrite('C:\\Users\\Administrator\\Desktop\\d.png',img)
# Out:
# (251, 556, 3)
# True

# %%
img1 = cv2.imread('C:\\Users\\Administrator\\Desktop\\a.png',1)
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
print(img1.shape)
img1 = cv2.resize(img1,(100, 86))
plt.figure(figsize=(1.5,1.5))
plt.imshow(img1)
plt.show()
# Out:
# (333, 500, 3)
