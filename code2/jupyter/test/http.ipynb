# %%
import requests
import json

# %%
names = 'zhangbo279,caixiang22,gongjuntai,xuyadong5,lisaiyu,lisaiyu,lisaiyu,wudawei5,zhangwen415,zhangkai83,lipeipei20,xiaoaijun1,weilai15,wangzhiwei42,wangzhiwei42,heyanting4,liyanlong7,lilili44,mashuqin1,lilili44,youyue7,heyanting4,lisaiyu,duzhixiang,dingkuiyun1,lichao283,liyuan268,heyang12,liuyanfang7,wangyinchu,liujunhong4,wangjunwei18,wangguohui12,jrmenglei1,zhouliye3,yangtianyi,yangtianyi,pengfu16,lvxuefen,lizhixian12,wangyang123019,tangliming2,huyao3,ouyangou,xulibin6,mamingyu6,liyong441,huyao3,liyong427,liuxiaorong17,lihuapeng,liyanjin3,shemin2,huanglvjun,kangyemeng,songyuhang4,sunchong5,lumin49,dengxinting,lijing165,jiaru30,lihaitao22,wanglixin16,renjing37,dingli8,yuchongchong1,yuchongchong1,zhaolicheng1,gaochao28,sunyi3,sunying1,yangtianyi,liyingjie14,liyingjie14,dongshanchuan,tangyaping,wangmingxin6,wangyingli17,mashuqin1,chenxi29,mengshuo3,fantao19,zhangjin623,jiheng3,dujunli3,huanghailong9,longxiaoyun,dujunli3,yanghongyu14,weihongli5,huanglvjun,zhaoweibo7,songsimeng,songsimeng,luxuan6,niuboyang,yangqi12,yuwanqing,zhangwen11,zhuhai56,zhuhao6,bijiankun,zhangmingjin7,yangxiaohe,wangshun54,chenqianqian17,huanghailong9,zhangqiao33,liuqiongzhi,cuitingting4,lilong74,lilong74'

# %%
import json

print(url)
cookStr = 'jd.erp.lang=zh_CN; userErp=mushudong; userErp.sig=fanfoi2cZXmw4knG3gCf5c-Gmc2WkPTKrxyb6N1kl0A; roles=manager_scheduler; roles.sig=bnFkDWLSekbjBQb1N1NNhFuNFkwLbFiBxVSnpfA4h9g; shshshfp=25dc9a008e66cea3b1cd433f2f73683b; shshshfpa=77e49345-7957-ec63-6eed-9cb7c2642121-1555045727; shshshfpb=sevmOuiJ4EqgdSTZ%2Fy3kWJg%3D%3D; _gcl_au=1.1.388619658.1555045727; 3AB9D23F7A4B3C9B=MT5JKZVFJJJIEVOKC2INUZ4MX6M5KZJGOBXPCMSLTVRHPPJHISFNJ44XI3DP7G2D6IEMIKWAXDFD3XAWFTTPGR37VQ; qd_uid=JUDM6J59-387M7H0ALQF9XB1R9WL4; qd_fs=1555045904491; qd_ls=1555045904491; _jrda=2; qd_ts=1555305832809; qd_sq=2; __jdu=15546969127801704096883; EBSAuthCookie=34130|||N; jd_erp_preAuthCookie=19af2c5bee834b1e8205b7d7dc938374; jd_ebs_ssoproxy=success; PROD=mobnzIOfGSWeSyUrSGVgBPLmcv; jd_loginUser.sig=YcVyCBtCWWg81ojSvJaHfVXApOTghvd_tNfuycHbD28; SSOID=4665ee3f7ed7ab7ff316f1d45c171db241cd91f15eb5e54bc52ed81492b7b4f5,mushudong; __jdc=238555101; __jda=238555101.15546969127801704096883.1554696913.1555905022.1555907557.9; erp1.jd.com=3BE820B06370F88EE4B6BEF670C2B4ACD80EE07B1A27344F0AC222031FD27177775032DA1AFD1C2BA23E2568EA2B1366BE78378A3CCA81CF5CD8B28D4C3D9AEC9499B7EFAFA03F6D3B35DF9F47AA941D; sso.jd.com=5c0a0e23369149c2a4685655aa8ab10a; jd_loginUser=%u7A46%u8FF0%u4E1C; _jrbdp_lc_=CZEY26TY6WSCGNXTNPEC3ZPJTU; JSESSIONID=65024886EB11A1E6A09048DCBBF7A5FD.s1';
cook = {}
for line in cookStr.split(";"):
    name,value = line.strip().split('=',1)
    cook[name]=value
for name in names.split(","):
    url = 'http://rx.jrbdp.jd.com/rx/category/getErpUserInfo?erp=%s'%name
    response = requests.get(url,cookies=cook)
    text = json.loads(response.text)
    print(name ,' ',text.get('respParam').get('organizationFullName'))
# Out:
# http://rx.jrbdp.jd.com/rx/category/getErpUserInfo?erp=mushudong
# zhangbo279   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# caixiang22   京东集团-京东数字科技-Alpha业务部-广告业务部-数据研发组
# gongjuntai   京东集团-京东数字科技-数字技术中心-数据资产部-智能平台部
# xuyadong5   京东集团-京东数字科技-数字技术中心-数据资产部-智能平台部
# lisaiyu   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# lisaiyu   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# lisaiyu   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# wudawei5   京东集团-京东数字科技-Alpha业务部-广告业务部-数据研发组
# zhangwen415   京东集团-京东数字科技-智能城市事业部-数据管理平台部
# zhangkai83   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# lipeipei20   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# xiaoaijun1   京东集团-京东数字科技-大资管事业部-资产管理业务部-研发部-研发一组
# weilai15   京东集团-京东数字科技-个人服务群组-个人风险管理中心-智能模型实验室-创新算法研究组
# wangzhiwei42   京东集团-京东数字科技-Alpha业务部-广告业务部-数据研发组
# wangzhiwei42   京东集团-京东数字科技-Alpha业务部-广告业务部-数据研发组
# heyanting4   京东集团-京东数字科技-个人服务群组-个人风险管理中心-智能模型实验室-创新算法研究组
# liyanlong7   京东集团-京东数字科技-创新科技业务部-创新孵化部-行业研究组
# lilili44   京东集团-京东数字科技-个人服务群组-个人风险管理中心-贷款策略部-金条策略组
# mashuqin1   京东集团-京东数字科技-数字技术中心-数据资产部-数据工程部
# ...

# %%
# Out:
# {"respCode":10000,"respMsg":"操作成功","respParam":{"age":"107.0","birthday":"1989-11-12 00:00:00","email":"mushudong@jd.com","headImg":"http://img20.360buyimg.com/ee/jfs/t26926/328/1999830214/31614/672df9ca/5bf3ac11Ne24500d0.jpg","mobile":"13611124644","organizationCode":"00052890","organizationFullName":"京东集团-京东数字科技-智能大数据部-数据资产部-图计算平台部","organizationFullPath":"/00000000/00008987/00055926/00040549/00052890","organizationName":"图计算平台部","positionCode":"00217269","positionName":"软件开发工程师岗","realName":"穆述东","sex":"男","telephone":"","userCode":"00630402","userName":"mushudong","workState":"102"}}

# %%
i = 0
with open(r'C:\Users\mushudong\Desktop\group.txt','r',encoding='utf-8') as f:
    while True:
        line = f.readline()
        if line:
            print(line)
            i=i+1
            if i > 5:
                break
# Out:
# 主键
#
# 188.0	xulibin6	京东数字科技
#
# 294.0	tangjie16	京东数字科技
#
# 295.0	wangting180	京东数字科技
#
# 330.0	zhangdengfeng4	京东数字科技
#
# 387.0	lijiahong3	京东数字科技

# %%
import random
import time
import hashlib
PASSWORD='EDKJK3323#@!kld'
randomstr = ''.join(random.sample('abcdefghij123456789',5))
timenow = int(time.time())
token_str_list = [PASSWORD,randomstr,str(timenow)]
token_str_list.sort()
token_str=''.join(token_str_list).encode('utf-8')
m1 = hashlib.md5()
m1.update(token_str)
token=m1.hexdigest()

# %%
import requests
import json
import time
i = 0
# jobStr = "STG_M20_CF_MERCHANTNO,STG_M20_CF_PLANRELATION,STG_M2U_CFE_COMPANY_INFO,STG_M2U_CFE_REAL_AUTH,STG_M2U_CFE_USER_INFO,STG_MY230_SUBSCRIBE_COUPON,STG_M0U_LOAN_APPLY,STG_M0U_REPAY_PLAN,STG_M0U_REPAY_RESULT,STG_J06_JD_FCASH_DAYSETTLE_ACCOUNT,STG_J06_JD_FCASH_DAYSETTLE_DELIN,STG_J06_JD_FCASH_LENDPAY_INFO,STG_M0C_CF_ASSET,STG_M64_FIN_SETT,STG_M2G_FDD_ORDER,STG_M2G_FDD_ORDER_PAYMENT,STG_M74_REBATE_ORDER,STG_M27_BIZ_CUST_ACCOUNT,STG_M27_BIZ_CYCLE_DETAIL,STG_M27_BIZ_CYCLE_SUMMARY,STG_M27_BIZ_IOU_RECEIPT,STG_S14_ORDERS,STG_M4E_ASSET_EXTRACT_BASE,STG_M4E_ASSET_EXTRACT_BATCH,STG_M4E_ASSET_EXTRACT_DETAIL,STG_M4E_ASSET_REPAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_RECORD,STG_M4E_SPECIAL_PLAN_REMAIN,STG_M0Q_LOAN_PERIOD_DAY_SETTLE,STG_MY493_FIN_SUBJECT_MERCHANT,STG_M63_ACCOUNTS,STG_M32_FLIGHTPOLICY,STG_M32_FREIGHTORDERS,STG_M32_FREIGHTPOLICIES,STG_M32_TRAINPOLICY,STG_M44_GLOBALORDER,STG_M1B_INS_TRANSFER,STG_M91_CUSTOMER_PRODUCT_PARAM,STG_M91_DAY_INTEREST,STG_M91_FINANCE_PRODUCT_PARAM,STG_M91_LOAN,STG_M91_REPAYMENT,STG_MY1030_TRANSFER,STG_M11_PROJECT,STG_M11_PROJECTDETAIL,STG_M11_PROJECTREDOUND,STG_M11_PROJECTREFUND,STG_M11_PROJECTSUBSCRIBE,STG_MY169_PAYMENTRECORD,STG_MY169_PURCHASERECORD,STG_M0G_ORDER_DETAIL,STG_M0G_PAY_INFO,STG_M0G_PRODUCTS_INFO,STG_M0G_REDEMPTION_INFO,STG_MY459_TAD_TRADE_BASE_000,STG_MY1051_ORDER_0000,STG_MY1051_PAYMENT_DETAIL_0000,STG_MY573_CM_ACCOUNT,STG_MY573_CM_CUSTOMER,STG_MY573_CM_USER,STG_MY576_BTA_ACCOUNT,STG_MY576_BTA_AGREEMENT_LOG,STG_MY576_BTA_DAYSUM,STG_MY576_BTA_OPERATE_RECORD,STG_MY577_BTA_WAITSALE_ASSETS,STG_MY346_O_ORDER_PRODUCT_00,STG_MY341_O_ORDER_00,STG_MY348_O_SUB_ORDER_00,STG_MY351_O_ORDER_REFUND,STG_M4Y_CRPL_CASH_APPLY,STG_M4Y_CRPL_LOAN_APPLY,STG_M4Y_CRPL_REPAYMENT_FLOW,STG_M4Y_CRPL_REPAYMENT_RECORD,STG_M4D_INVESTOR_UNDERTAKE_FLOW_0000,STG_MY1070_JINTIAO_TRADE_LOG_0000,STG_MY296_JTJX_0000,STG_MY296_LOAN_0000,STG_MY296_OPERATION_RECORD_0000,STG_MY296_ORDER_0000,STG_MY296_OVERDUE_0000,STG_MY296_PLAN_0000,STG_MY296_REFUND_0000,STG_MY296_REPAYMENTDETAIL_0000,STG_MY296_REPAYMENTPAY_0000,STG_MY296_UNION_REPAY_RECORD_0000,STG_MY2_PAYMENTRESULT_001,STG_MY2_TRADEORDER_001,STG_M2V_FD_LOAN_FUND,STG_M2V_FD_PLAN_FUND,STG_M2V_FD_SUB_REPAY,STG_M2V_RFL_FEE_DETAIL,STG_M2V_RFL_LIMIT,STG_M2V_RFL_LOAN,STG_M2V_RFL_MERCHANT_APPLY,STG_M2V_RFL_MONEY_RECORD,STG_M2V_RFL_PLAN,STG_M2V_RFL_PROJECT,STG_M2V_RFL_REPAY,STG_M2V_RFL_REPAY_MAPPING,stg_my1120_binlog_test"
# jobStr = "STG_M4E_ASSET_EXTRACT_BASE,STG_M4E_ASSET_EXTRACT_BATCH,STG_M4E_ASSET_EXTRACT_DETAIL,STG_M4E_ASSET_REPAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_RECORD,STG_M4E_SPECIAL_PLAN_REMAIN,STG_M2V_FD_LOAN_FUND,STG_M2V_FD_PLAN_FUND,STG_M2V_FD_SUB_REPAY,STG_M2V_RFL_FEE_DETAIL,STG_M2V_RFL_LIMIT,STG_M2V_RFL_LOAN,STG_M2V_RFL_MERCHANT_APPLY,STG_M2V_RFL_MONEY_RECORD,STG_M2V_RFL_PLAN,STG_M2V_RFL_PROJECT,STG_M2V_RFL_REPAY,STG_M2V_RFL_REPAY_MAPPING,STG_M44_GLOBALORDER,STG_M91_CUSTOMER_PRODUCT_PARAM,STG_M91_DAY_INTEREST,STG_M91_FINANCE_PRODUCT_PARAM,STG_M91_LOAN,STG_M91_REPAYMENT,STG_MY1030_TRANSFER,STG_M0Q_LOAN_PERIOD_DAY_SETTLE,STG_MY169_PAYMENTRECORD,STG_MY169_PURCHASERECORD,STG_J06_JD_FCASH_DAYSETTLE_ACCOUNT,STG_J06_JD_FCASH_DAYSETTLE_DELIN,STG_J06_JD_FCASH_LENDPAY_INFO,STG_M74_REBATE_ORDER,STG_MY493_FIN_SUBJECT_MERCHANT,STG_M27_BIZ_CUST_ACCOUNT,STG_M27_BIZ_CYCLE_DETAIL,STG_M27_BIZ_CYCLE_SUMMARY,STG_M27_BIZ_IOU_RECEIPT,STG_S14_ORDERS"
# jobStr = "STG_MY1070_JINTIAO_TRADE_LOG_0000,STG_MY296_JTJX_0000,STG_MY296_LOAN_0000,STG_MY296_OPERATION_RECORD_0000,STG_MY296_ORDER_0000,STG_MY296_OVERDUE_0000,STG_MY296_PLAN_0000,STG_MY296_REFUND_0000,STG_MY296_REPAYMENTDETAIL_0000,STG_MY296_REPAYMENTPAY_0000,STG_MY296_UNION_REPAY_RECORD_0000"
# jobStr = "STG_M0G_ORDER_DETAIL,STG_M0G_PAY_INFO,STG_M0G_PRODUCTS_INFO,STG_M0G_REDEMPTION_INFO"
# jobStr = "STG_M20_CF_MERCHANTNO,STG_M20_CF_PLANRELATION,STG_MY230_SUBSCRIBE_COUPON,STG_M0U_LOAN_APPLY,STG_M0U_REPAY_PLAN,STG_M0U_REPAY_RESULT,STG_J06_JD_FCASH_DAYSETTLE_ACCOUNT,STG_J06_JD_FCASH_DAYSETTLE_DELIN,STG_J06_JD_FCASH_LENDPAY_INFO,STG_M0C_CF_ASSET,STG_M64_FIN_SETT,STG_M2G_FDD_ORDER,STG_M2G_FDD_ORDER_PAYMENT,STG_M74_REBATE_ORDER,STG_M27_BIZ_CUST_ACCOUNT,STG_M27_BIZ_CYCLE_DETAIL,STG_M27_BIZ_CYCLE_SUMMARY,STG_M27_BIZ_IOU_RECEIPT,STG_S14_ORDERS,STG_M4E_ASSET_EXTRACT_BASE,STG_M4E_ASSET_EXTRACT_BATCH,STG_M4E_ASSET_EXTRACT_DETAIL,STG_M4E_ASSET_REPAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_DETAIL,STG_M4E_RECEIVABLE_PAYMENT_RECORD,STG_M4E_SPECIAL_PLAN_REMAIN,STG_M0Q_LOAN_PERIOD_DAY_SETTLE,STG_MY493_FIN_SUBJECT_MERCHANT,STG_M63_ACCOUNTS,STG_M32_FLIGHTPOLICY,STG_M32_FREIGHTORDERS,STG_M32_FREIGHTPOLICIES,STG_M32_TRAINPOLICY,STG_M44_GLOBALORDER,STG_M1B_INS_TRANSFER,STG_M91_CUSTOMER_PRODUCT_PARAM,STG_M91_DAY_INTEREST,STG_M91_FINANCE_PRODUCT_PARAM,STG_M91_LOAN,STG_M91_REPAYMENT,STG_MY1030_TRANSFER,STG_M11_PROJECT,STG_M11_PROJECTDETAIL,STG_M11_PROJECTREDOUND,STG_M11_PROJECTREFUND,STG_M11_PROJECTSUBSCRIBE,STG_MY169_PAYMENTRECORD,STG_MY169_PURCHASERECORD,STG_M0G_ORDER_DETAIL,STG_M0G_PAY_INFO,STG_M0G_PRODUCTS_INFO,STG_M0G_REDEMPTION_INFO,STG_MY459_TAD_TRADE_BASE_000,STG_MY1051_ORDER_0000,STG_MY1051_PAYMENT_DETAIL_0000,STG_MY573_CM_ACCOUNT,STG_MY573_CM_CUSTOMER,STG_MY573_CM_USER,STG_MY576_BTA_ACCOUNT,STG_MY576_BTA_AGREEMENT_LOG,STG_MY576_BTA_DAYSUM,STG_MY576_BTA_OPERATE_RECORD,STG_MY577_BTA_WAITSALE_ASSETS,STG_MY346_O_ORDER_PRODUCT_00,STG_MY341_O_ORDER_00,STG_MY348_O_SUB_ORDER_00,STG_MY351_O_ORDER_REFUND,STG_M4Y_CRPL_CASH_APPLY,STG_M4Y_CRPL_LOAN_APPLY,STG_M4Y_CRPL_REPAYMENT_FLOW,STG_M4Y_CRPL_REPAYMENT_RECORD,STG_M4D_INVESTOR_UNDERTAKE_FLOW_0000,STG_MY1070_JINTIAO_TRADE_LOG_0000,STG_MY296_JTJX_0000,STG_MY296_LOAN_0000,STG_MY296_OPERATION_RECORD_0000,STG_MY296_ORDER_0000,STG_MY296_OVERDUE_0000,STG_MY296_PLAN_0000,STG_MY296_REFUND_0000,STG_MY296_REPAYMENTDETAIL_0000,STG_MY296_REPAYMENTPAY_0000,STG_MY296_UNION_REPAY_RECORD_0000,STG_MY2_PAYMENTRESULT_001,STG_MY2_TRADEORDER_001,STG_M2V_FD_LOAN_FUND,STG_M2V_FD_PLAN_FUND,STG_M2V_FD_SUB_REPAY,STG_M2V_RFL_FEE_DETAIL,STG_M2V_RFL_LIMIT,STG_M2V_RFL_LOAN,STG_M2V_RFL_MERCHANT_APPLY,STG_M2V_RFL_MONEY_RECORD,STG_M2V_RFL_PLAN,STG_M2V_RFL_PROJECT,STG_M2V_RFL_REPAY,STG_M2V_RFL_REPAY_MAPPING,STG_M2U_CFE_COMPANY_INFO,STG_M2U_CFE_REAL_AUTH,STG_M2U_CFE_USER_INFO,stg_my1120_binlog_test"
jobStr = "STG_MY1120_BINLOG_TEST"
jobs = jobStr.split(',')
for job in jobs:
    i = i + 1
    print('第%d个作业%s' % (i,job))
    head = {"Content-Type": "application/json;charset=UTF-8"}
    body = {'jobName':job}
    requrl = "http://sync-jrbdp.jd.local/worker/startRealJob"
    r = requests.post(requrl, data=json.dumps(body),headers = head)
    print(r.text)
    time.sleep(2)
# Out:
# 第1个作业STG_MY1120_BINLOG_TEST
# {"result":"{\"timestamp\":\"2019-06-05T07:01:53.446+0000\",\"status\":500,\"error\":\"Internal Server Error\",\"message\":\"No message available\",\"path\":\"/real/job/start\"}","code":"1000","msg":"成功","success":1}

# %%
import requests
import json
import datetime
import time
cookStr = 'jd.erp.lang=zh_CN; __jdv=137720036|direct|-|none|-|1560994040116; __jdu=1560994040113463506734; SSOID="8f4c8dfa584a1fbdd99d496b192c824928f36ca98ddd58636c8496f87d1d6be9,mushudong"; areaId=1; ipLoc-djd=1-2809-0-0; _jrda=1; 3AB9D23F7A4B3C9B=MT5JKZVFJJJIEVOKC2INUZ4MX6M5KZJGOBXPCMSLTVRHPPJHISFNJ44XI3DP7G2D6IEMIKWAXDFD3XAWFTTPGR37VQ; isProd=true; isProd.sig=plIMPUdb2-tgaw9OZJMlYRKbBruzWlNobyMlo6vAkfI; userErp=mushudong; userErp.sig=fanfoi2cZXmw4knG3gCf5c-Gmc2WkPTKrxyb6N1kl0A; roles=manager_scheduler; roles.sig=bnFkDWLSekbjBQb1N1NNhFuNFkwLbFiBxVSnpfA4h9g; erp1.jd.com=5D3A75B9748E6C88F37AF9E911A4A533ABD6956AE3A52C740B0115E8B173B1BC2DF4F85E9A6DF14CC2DCDE62E44895D8B03B44533C3749645218A3AE0EB43CB229E46C0A9616B7D8472FB16909D71293; sso.jd.com=150926157f10477d9fdb6c1e8a0b733b; jd_loginUser=%u7A46%u8FF0%u4E1C; jd_loginUser.sig=YcVyCBtCWWg81ojSvJaHfVXApOTghvd_tNfuycHbD28; __jdc=50436146; __jda=50436146.1560994040113463506734.1560994040.1562216416.1562225706.34; __jdb=50436146.1.1560994040113463506734|34.1562225706';
cook = {}
for line in cookStr.split(";"):
    name,value = line.strip().split('=',1)
    cook[name]=value
head = {"Content-Type": "application/json;charset=UTF-8","cookie":cookStr}
runDate=datetime.datetime.strptime("2019-03-12", "%Y-%m-%d")
while runDate < datetime.datetime.strptime("2019-06-25", "%Y-%m-%d"):
    body = {'jobNames':["STG_SP15_TM_GOODS_1"],'txDate':runDate.strftime("%Y-%m-%d")}
    requrl = "http://particle.jrbdp.jd.com/particle/job/sched/forceJobBatch"
    r = requests.post(requrl, data=json.dumps(body),headers = head)
    result = json.loads(r.text)
    print(result.get("msg"))
    print(result)
    time.sleep(60)
    if result.get("code") == "1004":
        print("没成功,休息60s")
        time.sleep(60)
    else:
        runDate=runDate + datetime.timedelta(days = 1)
# Out:
# 成功
# {'result': None, 'msg': '成功', 'code': '1000', 'success': 1}
# 重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]
# {'msg': '重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]', 'code': '1004', 'success': 0}
# 没成功,休息60s
# 成功
# {'result': None, 'msg': '成功', 'code': '1000', 'success': 1}
# 重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]
# {'msg': '重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]', 'code': '1004', 'success': 0}
# 没成功,休息60s
# 成功
# {'result': None, 'msg': '成功', 'code': '1000', 'success': 1}
# 重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]
# {'msg': '重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]', 'code': '1004', 'success': 0}
# 没成功,休息60s
# 成功
# {'result': None, 'msg': '成功', 'code': '1000', 'success': 1}
# 重跑成功任务0个，失败1个，失败任务：["STG_SP15_TM_GOODS_1--原因：作业有其它实例正在Ready或Running"]
# ...

# %%
import requests
import json
import time
jobName = "s_m0b_customer_000"
head = {"Content-Type": "application/json;charset=UTF-8"}
body = {'jobName':jobName}
requrl = "http://sync-jrbdp.jd.local/worker/getRealTimeJobRunInfo"
r = requests.post(requrl, data=json.dumps(body),headers = head)
print(r.text)
# Out:
# {"code":1003,"msg":"nodename不能为空","success":0}

# %%
import requests
import json
import time
head = {"Content-Type": "application/json;charset=UTF-8"}
body = {'mobile':'13611124644','content':'咚咚 动态码'}
requrl = "http://sync-jrbdp.jd.local/msg/sendMsg"
r = requests.post(requrl, data=json.dumps(body),headers = head)
print(r.text)
# Out:
# {"result":"","code":"1000","msg":"成功","success":1}

# %%
import requests
import json
import time
jobName = "S_Z28_BALANCE_TALLY_FLOW"
head = {"Content-Type": "application/json;charset=UTF-8"}
body = {'jobName':jobName,'txDate':'2019-11-17'}
requrl = "http://sync-jrbdp.jd.local/worker/getRunData"
r = requests.post(requrl, data=json.dumps(body),headers = head)
print(r.text)
# Out:
# {"result":{"jobName":"S_Z28_BALANCE_TALLY_FLOW","txDate":"2019-11-17","dataContent":"{\"job\":{\"setting\":{\"speed\":{\"channel\":8}},\"content\":[{\"reader\":{\"name\":\"mysqlreader\",\"parameter\":{\"column\":[\"`tally_flow_id`\",\"`trade_no`\",\"`biz_no`\",\"`balance_pin`\",\"`type_code`\",\"`flow_type`\",\"DATE_FORMAT(`trade_time`,'%Y-%m-%d %H:%i:%s')\",\"`from_type`\",\"`amount`\",\"`real_amount`\",\"`amount_usd`\",\"`real_amount_usd`\",\"`content`\",\"`img_url`\",\"`remark`\",\"`db_status`\",\"`trade_status`\",\"`pay_way`\",\"`bankcode`\",\"`bankcard_num`\",\"`db_status2`\",\"`created`\",\"DATE_FORMAT(`created_date`,'%Y-%m-%d %H:%i:%s')\",\"`modified`\",\"DATE_FORMAT(`modified_date`,'%Y-%m-%d %H:%i:%s')\"],\"where\":\"((created_date >= DATE('2019-11-17 00:00:00') AND created_date < DATE('2019-11-18 00:00:00')) OR (modified_date >= DATE('2019-11-17 00:00:00') AND modified_date < DATE('2019-11-18 00:00:00')))\",\"splitPk\":\"tally_flow_id\",\"connection\":[{\"username\":\"jdjr_b
# ...
